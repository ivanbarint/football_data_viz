# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()

# %%
for i in range(2000, 2023):
    season = f"{i}-{i+1}"
    site = f"https://fbref.com/en/comps/Big5/{season}/shooting/players/{season}-Big-5-European-Leagues-Stats"
    page = pd.read_html(site)
    frame = page[0]
    frame.columns = frame.columns.droplevel(0)
    frame = frame[frame['Gls'].notna()]
    frame = frame[frame['Gls'] != 'Gls']
    frame['Gls'] = frame['Gls'].astype(int)
    frame['Season'] = i+1
    
    df = pd.concat([df, frame])
    print(f"{season} is done")
# Out:
# 2000-2001 is done
# 2001-2002 is done
# 2002-2003 is done
# 2003-2004 is done
# 2004-2005 is done
# 2005-2006 is done
# 2006-2007 is done
# 2007-2008 is done
# 2008-2009 is done
# 2009-2010 is done
# 2010-2011 is done
# 2011-2012 is done
# 2012-2013 is done
# 2013-2014 is done
# 2014-2015 is done
# 2015-2016 is done
# 2016-2017 is done
# 2017-2018 is done
# 2018-2019 is done
# 2019-2020 is done
# 2020-2021 is done
# 2021-2022 is done
# 2022-2023 is done

# %%
goals = df[['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', '90s', 'Gls', 'PK', 'xG', 'npxG']]
goals = goals[goals['xG'].notna()]

# %%
goals['npGls'] = goals['Gls'] - goals['PK'].astype(float)
goals['npxG'] = goals['npxG'].astype(float)

# %%
goals = goals.groupby(['Player'], as_index=False).sum()

goals['Diff'] = goals['npGls'] - goals['npxG']
goals = goals.sort_values(by=['Diff'])

# %%
goals.head(20)
# Out:
#                  Player  Gls   npxG  npGls  Diff
# 1371         Edin Džeko  130  165.6  130.0 -35.6
# 2875      Kevin Lasagna   70   95.4   70.0 -25.4
# 3134    Lorenzo Insigne  112   90.8   66.0 -24.8
# 1784      Gabriel Jesus  112  132.4  108.0 -24.4
# 894   Christian Benteke   40   62.0   38.0 -24.0
# 4855       Sergi Enrich   28   48.0   28.0 -20.0
# 3229      Lucas Ocampos   76   77.6   58.0 -19.6
# 3979        Neal Maupay   54   63.4   44.0 -19.4
# 4599    Rodrigo Palacio   38   57.2   38.0 -19.2
# 2535   Jonathan Calleri   48   53.0   34.0 -19.0
# 2208     Iñaki Williams   90  102.8   84.0 -18.8
# 1213    Denis Cheryshev   10   28.6   10.0 -18.6
# 5084      Tammy Abraham   92  104.4   86.0 -18.4
# 4049   Nicolás González   38   44.0   26.0 -18.0
# 3765    Michail Antonio   82   97.6   80.0 -17.6
# 3804    Mijat Gaćinović    2   19.4    2.0 -17.4
# 2817   Karl Toko Ekambi  130  136.6  120.0 -16.6
# 2353      Jay Rodriguez   36   48.4   32.0 -16.4
# 5022       Steve Mounié   54   64.2   48.0 -16.2
# 3224        Lucas Höler   48   64.0   48.0 -16.0

# %%
goals.tail(20)
# Out:
#                Player  Gls   npxG   Season  npGls  Diff
# 1945   Gonçalo Guedes   29   17.3  14141.0   28.0  10.7
# 417        Ante Rebić   42   31.1  14143.0   42.0  10.9
# 4090    Nils Petersen   49   29.6  12123.0   41.0  11.4
# 2245     Jadon Sancho   43   30.4  12123.0   42.0  11.6
# 2273   James Maddison   39   26.1  10105.0   38.0  11.9
# 5420    Wilfried Zaha   54   34.8  12123.0   47.0  12.2
# 2975    Kylian Mbappé  130  105.7  14141.0  118.0  12.3
# 2016       Harry Kane  116   84.6  12123.0   98.0  13.4
# 4850     Serge Gnabry   63   49.4  12123.0   63.0  13.6
# 3544   Martin Terrier   51   33.8  12123.0   48.0  14.2
# 3263      Luis Muriel   64   38.4  14142.0   53.0  14.6
# 4286     Paulo Dybala   57   35.3  12123.0   50.0  14.7
# 4544     Riyad Mahrez   51   31.2  12123.0   46.0  14.8
# 2871  Kevin De Bruyne   47   27.8  12123.0   43.0  15.2
# 1493   Erling Haaland   80   51.5   8086.0   69.0  17.5
# 1327    Dries Mertens   63   39.1  10100.0   57.0  17.9
# 944     Ciro Immobile  133   76.3  12123.0   96.0  19.7
# 2080       Iago Aspas   95   53.2  12123.0   74.0  20.8
# 4970    Son Heung-min   78   53.7  12123.0   77.0  23.3
# 3112     Lionel Messi  138   95.7  12123.0  124.0  28.3
